# %%
import os
opb = os.path.basename
opd = os.path.dirname
from pathlib import Path
from datetime import datetime
from time import time
import random
import json
import shutil as sh
import argparse
##
from PIL import Image
##
import numpy as np
##
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
from matplotlib import pyplot as plt
import cv2

# %%
def plt_img(img, debug=0):
    '''

    '''
    ##
    dpi_val = 100
    fig = plt.figure(figsize=(512/dpi_val, 512/dpi_val), dpi=dpi_val)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.imshow(img, aspect='equal', cmap='gray')
    
def read_tiff(addr_img):
    '''
    Save in grayscale
    '''

    img = Image.open(addr_img).convert('L')
    img = np.array(img).astype(np.double)
    
    return img
                     
img = read_tiff('rfp0.tiff')
mask = np.zeros((512,512))
posx, posy = 400,400
mask[posx-20:posx+20, posy-20:posy+20] = img[posx-20:posx+20, posy-20:posy+20]
#plt.imshow(mask)
plt_img(mask)
plt.savefig('part.tiff')

# %%
plt.imshow(img)

# %%
def plt_img(img, debug=0):
    '''

    '''
    ##
    dpi_val = 100
    fig = plt.figure(figsize=(512/dpi_val, 512/dpi_val), dpi=dpi_val)
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.imshow(img, aspect='equal', cmap='gray')

def read_tiff(addr_img):
    '''
    Save in grayscale
    '''

    img = Image.open(addr_img).convert('L')
    img = np.array(img).astype(np.double)

    return img


addr_fluo = 'rfp0.tiff'
curr_img_fluo = read_tiff(addr_fluo)     #cv2.imread(str(addr_fluo), cv2.IMREAD_GRAYSCALE)
mask = np.zeros((512,512))
posx, posy = 182,83
mask[posx-20:posx+20, posy-20:posy+20] = curr_img_fluo[posx-20:posx+20, posy-20:posy+20]
addr_img = 'img1.tiff' 
plt_img(mask)
plt.savefig( addr_img )       # save frame in self.output_folder

# %%
#83, 182
